# %% [markdown]
# Task A

# %%
a = int(input())
b = int(input())
if(a>b):
    print(a)
else:
    print(b)
# Out:
# 8

# %% [markdown]
# Task B

# %%
year = int(input())
if((year%4 == 0 and year%100 != 0) or year%400 == 0):
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# Task C

# %%
a = int(input())
b = int(input())

if((a==1)==(b==1)):
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# Task D

# %%
x = int(input())

if(x>0):
    print(1)
elif(x<0):
    print(-1)
else:
    print(0)
# Out:
# 1

# %% [markdown]
# Task E

# %%
a = int(input())
b = int(input())

if(a>b):
    print(1)
elif(b>a):
    print(2)
else:
    print(0)
# Out:
# 2
