# %% [markdown]
# Task A

# %%
n = int(input())
i = 1

while i * i <= n:
    print(i * i)
    i += 1

# %% [markdown]
# Task B

# %%
x = int(input())
i = 2

while i*i<=x:
    if x % i == 0:
        print(i)
        break
    i+=1
else:
    print(x)
# Out:
# 3

# %% [markdown]
# Task C

# %%
n = int(input())
i = 1

while i<=n:
    print(i, end=' ')
    i *= 2
# Out:
# 1 2 4 8 16 32

# %% [markdown]
# Task D

# %%
n = int(input())

while n > 1 and n % 2 == 0:
    n //= 2

if n == 1:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# Task E

# %%
n = int(input())
v = 1
k = 0

while v < n:
    v *= 2
    k += 1

print(k)
# Out:
# 3
